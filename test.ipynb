# %%
# %reload_ext autoreload

# %autoreload 2

# %%
from src import Portfolio, Stocks, Screener, Strategy

# %%
screener = Screener(1e+9, 'br')
screener.screen()
# Out:
# ['PETR3.SA',
#  'PETR4.SA',
#  'ITUB3.SA',
#  'ITUB4.SA',
#  'BPAC5.SA',
#  'VALE3.SA',
#  'ABEV3.SA',
#  'BPAC3.SA',
#  'WEGE3.SA',
#  'BBDC3.SA',
#  'BBDC4.SA',
#  'AXIA5.SA',
#  'ITSA3.SA',
#  'ITSA4.SA',
#  'AXIA6.SA',
#  'AXIA3.SA',
#  'BBAS3.SA',
#  'VIVT3.SA',
#  'SANB4.SA',
#  'SBSP3.SA',
#  'SANB3.SA',
#  'B3SA3.SA',
#  'JBSS32.SA',
#  'RDOR3.SA',
#  'BBSE3.SA',
#  'TIMS3.SA',
#  'SUZB3.SA',
#  'PRIO3.SA',
#  'CPFE3.SA',
#  'CXSE3.SA',
#  'EMBJ3.SA',
#  'PRXB31.SA',
#  'ENEV3.SA',
#  'EQTL3.SA',
#  'RENT3.SA',
#  'GGBR4.SA',
#  'RENT4.SA',
#  'XPBR31.SA',
#  'CMIG3.SA',
#  'CPLE3.SA',
#  'GGBR3.SA',
#  'VBBR3.SA',
#  'EGIE3.SA',
#  'EQPA5.SA',
#  'RADL3.SA',
#  'AURA33.SA',
#  'CMIG4.SA',
#  'UGPA3.SA',
#  'PSSA3.SA',
#  'ENGI3.SA',
#  'MOTV3.SA',
#  'RAIL3.SA',
#  'CMIN3.SA',
#  'MBRF3.SA',
#  'ENGI4.SA',
#  'ISAE3.SA',
#  'KLBN3.SA',
#  'KLBN4.SA',
#  'CSMG3.SA',
#  'ISAE4.SA',
#  'TOTS3.SA',
#  'AZUL3.SA',
#  'CSAN3.SA',
#  'CGAS3.SA',
#  'CGAS5.SA',
#  'REDE3.SA',
# ...

# %%
stock_selection = Stocks(screener.local_stocks_names)
set1 = stock_selection.random_selection(5, '7Y')
# Out:
# random_stocks_list pre: []
# random_stocks_list pos: []
# entrei no while
# entrei no while

# %%
strategy1 = Strategy(set1, '7Y', strategy_type='min_variance_weights', aggregate=True)
strategy2 = Strategy(set1, '7Y', strategy_type='min_variance_weights', aggregate=False)
strategy3 = Strategy(set1, '7Y')
# Out:
# [*********************100%***********************]  5 of 5 completed
# [*********************100%***********************]  5 of 5 completed
# [*********************100%***********************]  5 of 5 completed

# %%
port1 = Portfolio(strategy1, 'port1')
port1.create_port()

port2 = Portfolio(strategy2, 'port2')
port2.create_port()

port3 = Portfolio(strategy3, 'port3')
port3.create_port()
# Out:
# rebalance at: 2019-06-24 00:00:00
#
# post fee rebalance: Ticker
# BBDC3.SA    -17.904761
# BPAC5.SA   -169.655424
# BRKM5.SA   -185.376569
# GOAU3.SA    418.609189
# LIGT3.SA    -45.722435
# dtype: float64 (total fee: 8.372383772508444)
#
# rebalance at: 2019-08-06 00:00:00
#
# post fee rebalance: Ticker
# BBDC3.SA     57.029027
# BPAC5.SA    -28.199083
# BRKM5.SA     39.368360
# GOAU3.SA   -145.204258
# LIGT3.SA     76.955955
# dtype: float64 (total fee: 3.467666821032878)
#
# rebalance at: 2019-09-17 00:00:00
#
# post fee rebalance: Ticker
# BBDC3.SA   -43.097844
# BPAC5.SA    23.117783
# BRKM5.SA     1.805113
# GOAU3.SA   -28.785859
# LIGT3.SA    46.910807
# dtype: float64 (total fee: 1.437274062970107)
#
# rebalance at: 2019-10-29 00:00:00
#
# post fee rebalance: Ticker
# BBDC3.SA    16.904328
# BPAC5.SA     7.188958
# BRKM5.SA    22.571541
# GOAU3.SA   -58.991125
# LIGT3.SA    12.276299
# dtype: float64 (total fee: 1.1796224937673052)
#
# rebalance at: 2019-12-12 00:00:00
#
# ...

# %%
port1.analyse()
port2.analyse()
port3.analyse()
# Out:
# d:\Projects\Markowitz\src\portfolio.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#
# [*********************100%***********************]  1 of 1 completed
# total return (index = 1):
# port1    2.466931
# IBOV     1.930711
# dtype: float64
#
# standard deviation in %:
# port1    1.729626
# IBOV     1.482932
# dtype: float64%
# c:\Users\Vinicius\AppData\Local\Programs\Python\Python314\Lib\site-packages\numpy\_core\fromnumeric.py:4062: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# d:\Projects\Markowitz\src\portfolio.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#
# [*********************100%***********************]  1 of 1 completed
# total return (index = 1):
# port2    1.809268
# ...
